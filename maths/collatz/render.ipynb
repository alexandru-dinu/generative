# %%
import cv2
import numpy as np
from PIL import Image

# %%
def collatz(n):
    if n == 1:
        return []
    
    if n & 1:
        n = 3 * n + 1

    else:
        n = n//2

    return [n] + collatz(n)

# %%
img = np.zeros((400,400), dtype=np.float32)
cv2.circle(img, (200,200), 100, color=0.5)

plt.figure(figsize=(10,10))
plt.imshow(img)
